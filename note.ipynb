# %%
from src.chunks.retrieve import retrieve_tool_chunks

sample_query = "i want to move data.zip file to src/data.zip"
retrieved = retrieve_tool_chunks(sample_query, top_k=3)
for idx, item in enumerate(retrieved, start=1):
    print(f"{idx}. [{item.server}] {item.tool_name} (score={item.score})")
# Out:
# 1. [filesystem] move_file (score=0.8815041184425354)
# 2. [filesystem] write_file (score=0.7172014713287354)
# 3. [filesystem] append_file (score=0.7134153842926025)
